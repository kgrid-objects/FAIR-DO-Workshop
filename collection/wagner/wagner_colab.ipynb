# %% [markdown]
# # Wagner CLI on Google Colab
#
# This notebook clones the repository and runs `npx wagner`.
# Run cells in order.

# %%
# !git clone https://github.com/kgrid-objects/FAIR-DO-Workshop.git /content/FAIR-DO-Workshop

# %cd /content/FAIR-DO-Workshop/collection/wagner

# %%
# Run the interactive questionnaire CLI.
# !npx wagner
